# %%
import cv2 
import numpy as np
path = "C:/Users/Srujan/Downloads/house.jpeg"
IMG_SIZE=500

# %%
img = cv2.imread(path,cv2.IMREAD_COLOR)
img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))
img_array = np.array(img)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)
plt.show()

# %%
cv2.imwrite('C:/Users/Srujan/Downloads/resize_house.jpeg', img)
# Out:
# True
